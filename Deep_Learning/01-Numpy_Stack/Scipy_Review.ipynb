# %%
from scipy.stats import norm
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('seaborn')
# %matplotlib inline

# %%
norm.pdf(0)
# Out:
# 0.3989422804014327

# %%
# mean = 5, std = 10
norm.pdf(0, loc=5, scale=10)
# Out:
# 0.035206532676429952

# %%
r = np.random.randn(10)

# %%
norm.logpdf(r)
# Out:
# array([-1.3239934 , -0.99507186, -1.21911786, -1.02852595, -0.93005419,
#        -2.74883555, -1.97994085, -1.95495219, -1.08933243, -1.29869011])

# %%
norm.cdf(r)
# Out:
# array([ 0.1840439 ,  0.65181069,  0.78077939,  0.31983469,  0.44073669,
#         0.02787026,  0.9274018 ,  0.92498901,  0.72031258,  0.19174203])

# %%
norm.logcdf(r)
# Out:
# array([-1.69258094, -0.42800111, -0.24746264, -1.13995103, -0.81930767,
#        -3.58019505, -0.07536836, -0.07797343, -0.32807002, -1.65160442])

# %%
r = np.random.randn(10000)

# %%
plt.hist(r,bins=100)
plt.show()

# %%
r = np.random.randn(10000,2)

# %%
plt.scatter(r[:,0], r[:, 1],linewidths=1,edgecolors='r',c='black')
plt.figure(figsize=(10,8))
plt.show()

# %%
r[:,1] = 5 * r[:,1] + 2
plt.scatter(r[:,0], r[:, 1],linewidths=1,edgecolors='r',c='black')
plt.figure(figsize=(10,8))
plt.show()

# %%
plt.axis('equal')
# Out:
# (-0.055000000000000007,
#  0.055000000000000007,
#  -0.055000000000000007,
#  0.055000000000000007)

# %%
cov = np.array([[1, 0.8], [0.8, 3]])

# %%
from scipy.stats import multivariate_normal as mvn

# %%
mu = np.array([0,2])
