# %%
from ggplot import *
import matplotlib.pyplot as plt

# %%
ggplot(aes(x='date', y='beef'), data=meat) + geom_line() + stat_smooth(colour='blue', span=0.2)
# Out:
# /Users/liyixuan1121/anaconda/lib/python3.6/site-packages/ggplot/stats/stat_smooth.py:77: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   smoothed_data = smoothed_data.sort('x')
# <ggplot: (-9223372029313193973)>

# %%
ggplot(diamonds, aes(x='carat', y='price', color='cut')) + geom_point() + \
                    scale_color_brewer(type='diverging', palette=4) + \
                    xlab("Carats") + ylab("Price") + ggtitle("Diamonds")
# Out:
# <ggplot: (7541559409)>

# %%
ggplot(diamonds, aes(x='price', fill='cut')) + \
        geom_density(alpha=0.25) + \
        facet_wrap("clarity")
# Out:
# <ggplot: (-9223372029308189717)>

# %%
diamonds.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
p = ggplot(aes(x='date', y ='beef'), data=meat)
p
# Out:
# <ggplot: (7540526351)>

# %%
p + geom_point()
# Out:
# <ggplot: (7540526351)>

# %%
p + geom_point() + geom_line()
# Out:
# <ggplot: (7540526351)>

# %%
p + geom_point() + geom_line() + stat_smooth(color='blue')
# Out:
# /Users/liyixuan1121/anaconda/lib/python3.6/site-packages/ggplot/stats/stat_smooth.py:77: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   smoothed_data = smoothed_data.sort('x')
# <ggplot: (7540526351)>
