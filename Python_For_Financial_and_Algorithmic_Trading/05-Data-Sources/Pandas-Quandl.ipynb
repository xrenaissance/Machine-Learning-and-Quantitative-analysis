# %%
import quandl
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline

# %%
# Return a pandas Series
mydata = quandl.get('EIA/PET_RWTC_D')

#Alternative way
#mydata = quandl.get('EIA/PET_RWTC_D', returns = 'numpy')

# %%
mydata.head()
# Out:
#             Value
# Date
# 1986-01-02  25.56
# 1986-01-03  26.00
# 1986-01-06  26.53
# 1986-01-07  25.85
# 1986-01-08  25.87

# %%
mydata.plot()

# %%
zillow_san_Fransico_estate = quandl.get('ZILLOW/CO47_PHSLAH')

# %%
zillow_san_Fransico_estate.head()
# Out:
#             Value
# Date
# 2011-05-31  26.79
# 2011-06-30  30.64
# 2011-07-31  31.52
# 2011-08-31  28.26
# 2011-09-30  28.99

# %%
zillow_san_Fransico_estate.plot()

# %%
apple_stock = quandl.get('WIKI/AAPL')

# %%
apple_stock.head()
# Out:
#              Open   High    Low  Close     Volume  Ex-Dividend  Split Ratio  \
# Date
# 1980-12-12  28.75  28.87  28.75  28.75  2093900.0          0.0          1.0
# 1980-12-15  27.38  27.38  27.25  27.25   785200.0          0.0          1.0
# 1980-12-16  25.37  25.37  25.25  25.25   472000.0          0.0          1.0
# 1980-12-17  25.87  26.00  25.87  25.87   385900.0          0.0          1.0
# 1980-12-18  26.63  26.75  26.63  26.63   327900.0          0.0          1.0
#
#             Adj. Open  Adj. High  Adj. Low  Adj. Close  Adj. Volume
# Date
# 1980-12-12   0.422706   0.424470  0.422706    0.422706  117258400.0
# 1980-12-15   0.402563   0.402563  0.400652    0.400652   43971200.0
# 1980-12-16   0.373010   0.373010  0.371246    0.371246   26432000.0
# 1980-12-17   0.380362   0.382273  0.380362    0.380362   21610400.0
# 1980-12-18   0.391536   0.393300  0.391536    0.391536   18362400.0

# %%
apple_stock.plot(figsize=(17,7))

# %%
apple_stock['Close'].plot()

# %%
bitcoin = quandl.get('BITSTAMP/USD')

# %%
bitcoin.head()
# Out:
#               High     Low    Last     Bid     Ask        Volume    VWAP
# Date
# 2014-04-15  515.00  453.16  499.01  500.01  505.04  28535.844106  491.41
# 2014-04-16  548.00  494.02  534.00  535.01  536.00  31159.941300  520.21
# 2014-04-17  537.24  481.63  506.52  504.70  505.38  21126.375080  504.83
# 2014-04-18  508.43  470.00  487.00  484.14  487.00  11879.484756  485.72
# 2014-04-19  507.43  472.81  504.74  504.74  505.00  10262.195861  492.22

# %%
bitcoin.plot()
