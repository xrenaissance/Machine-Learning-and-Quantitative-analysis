# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# %matplotlib inline

# %%
x = np.linspace(0, 5, 11)
y = x ** 2

# %%
x
# Out:
# array([ 0. ,  0.5,  1. ,  1.5,  2. ,  2.5,  3. ,  3.5,  4. ,  4.5,  5. ])

# %%
y
# Out:
# array([  0.  ,   0.25,   1.  ,   2.25,   4.  ,   6.25,   9.  ,  12.25,
#         16.  ,  20.25,  25.  ])

# %%
# Functional method
plt.plot(x, y, 'r-')
plt.xlabel('X Lable')
plt.ylabel('Y Label')
plt.title('Title')
plt.show()

# %%
plt.subplot(1, 2, 1)
plt.plot(x, y, 'r--')
plt.xlabel('X label')
plt.ylabel('Y label')
plt.title('x against y')

plt.subplot(1, 2, 2)
plt.plot(y, x, 'b*-')
plt.xlabel('X label')
plt.ylabel('Y label')
plt.title('Y against x')

plt.show()

# %%
plt.subplot(2,1,1)
plt.plot(x, y, 'r')

plt.subplot(2,1,2)
plt.plot(y, x, 'b')

plt.show()

# %% [markdown]
# # Object oriented method
#
# **Better to understand what does add_axes( [left, bottom, width, height] ) mean?**

# %%
fig = plt.figure()

# [left, bottom, width, height
axes = fig.add_axes([0.1, 0.1, 0.8, 0.8])

axes.plot(x, y, 'r--')
axes.set_xlabel('X label')
axes.set_ylabel('Y label')
axes.set_title('oo plot graph')
# Out:
# Text(0.5,1,'oo plot graph')

# %%
fig = plt.figure()

# [left, bottom, width, height
axes1 = fig.add_axes([0.1, 0.1, 0.8, 0.8])
axes2 = fig.add_axes([0.2, 0.5, 0.4,0.3])

axes1.plot(x, y, 'y-*')
axes1.set_title('Large plot')

axes2.plot(y, x, 'g--')
axes2.set_title('Small plot')
# Out:
# Text(0.5,1,'Small plot')

# %%
fig, axes = plt.subplots(nrows = 3, ncols = 3)

plt.tight_layout()

# %%
fig, axes = plt.subplots(nrows = 1, ncols = 2)

plt.tight_layout()

# %%
axes
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x11d09d8d0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x11d24a7b8>], dtype=object)

# %%
fig

# %%
fig, axes = plt.subplots(nrows = 1, ncols = 2)

axes[0].plot(x, y)
axes[0].set_title('First Plot')
axes[1].plot(y, x)
axes[1].set_title('Second Plot')
plt.tight_layout()

# %% [markdown]
# ### Figure size, aspect ratio and DPI

# %% [markdown]
# Matplotlib allows the aspect ratio, DPI and figure size to be specified when the Figure object is created. You can use the `figsize` and `dpi` keyword arguments.
# * `figsize` is a tuple of the width and height of the figure in inches
# * `dpi` is the dots-per-inch (pixel per inch).
#
# For example:
